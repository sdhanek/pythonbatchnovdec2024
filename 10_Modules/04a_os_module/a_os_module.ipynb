# %% [markdown]
# os module

# %%
import os

# %%
os
# Out:
# <module 'os' (frozen)>

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'CLONE_FILES',
#  'CLONE_FS',
#  'CLONE_NEWCGROUP',
#  'CLONE_NEWIPC',
#  'CLONE_NEWNET',
#  'CLONE_NEWNS',
#  'CLONE_NEWPID',
#  'CLONE_NEWUSER',
#  'CLONE_NEWUTS',
#  'CLONE_SIGHAND',
#  'CLONE_SYSVSEM',
#  'CLONE_THREAD',
#  'CLONE_VM',
#  'DirEntry',
#  'EFD_CLOEXEC',
#  'EFD_NONBLOCK',
#  'EFD_SEMAPHORE',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GRND_NONBLOCK',
#  'GRND_RANDOM',
#  'GenericAlias',
#  'MFD_ALLOW_SEALING',
#  'MFD_CLOEXEC',
#  'MFD_HUGETLB',
#  'MFD_HUGE_16GB',
#  'MFD_HUGE_16MB',
#  'MFD_HUGE_1GB',
#  'MFD_HUGE_1MB',
#  'MFD_HUGE_256MB',
#  'MFD_HUGE_2GB',
#  'MFD_HUGE_2MB',
#  'MFD_HUGE_32MB',
#  'MFD_HUGE_512KB',
#  'MFD_HUGE_512MB',
#  'MFD_HUGE_64KB',
#  'MFD_HUGE_8MB',
#  'MFD_HUGE_MASK',
#  'MFD_HUGE_SHIFT',
#  'Mapping',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_FSYNC',
#  'O_LARGEFILE',
#  'O_NDELAY',
#  'O_NOATIME',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_PATH',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_RSYNC',
#  'O_SYNC',
#  'O_TMPFILE',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_FADV_DONTNEED',
#  'POSIX_FADV_NOREUSE',
#  'POSIX_FADV_NORMAL',
#  'POSIX_FADV_RANDOM',
#  'POSIX_FADV_SEQUENTIAL',
#  'POSIX_FADV_WILLNEED',
#  'POSIX_SPAWN_CLOSE',
#  'POSIX_SPAWN_DUP2',
#  'POSIX_SPAWN_OPEN',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
#  'P_PIDFD',
#  'P_WAIT',
#  'PathLike',
#  'RTLD_DEEPBIND',
#  'RTLD_GLOBAL',
#  'RTLD_LAZY',
#  'RTLD_LOCAL',
#  'RTLD_NODELETE',
#  'RTLD_NOLOAD',
#  'RTLD_NOW',
#  'RWF_APPEND',
#  'RWF_DSYNC',
#  'RWF_HIPRI',
#  'RWF_NOWAIT',
#  'RWF_SYNC',
#  'R_OK',
#  'SCHED_BATCH',
#  'SCHED_FIFO',
#  'SCHED_IDLE',
#  'SCHED_OTHER',
#  'SCHED_RESET_ON_FORK',
#  'SCHED_RR',
#  'SEEK_CUR',
#  'SEEK_DATA',
#  'SEEK_END',
#  'SEEK_HOLE',
#  'SEEK_SET',
#  'SPLICE_F_MORE',
#  'SPLICE_F_MOVE',
#  'SPLICE_F_NONBLOCK',
#  'ST_APPEND',
#  'ST_MANDLOCK',
#  'ST_NOATIME',
#  'ST_NODEV',
#  'ST_NODIRATIME',
#  'ST_NOEXEC',
#  'ST_NOSUID',
#  'ST_RDONLY',
#  'ST_RELATIME',
#  'ST_SYNCHRONOUS',
#  'ST_WRITE',
#  'TMP_MAX',
#  'WCONTINUED',
#  'WCOREDUMP',
#  'WEXITED',
#  'WEXITSTATUS',
#  'WIFCONTINUED',
#  'WIFEXITED',
#  'WIFSIGNALED',
#  'WIFSTOPPED',
#  'WNOHANG',
#  'WNOWAIT',
#  'WSTOPPED',
#  'WSTOPSIG',
#  'WTERMSIG',
#  'WUNTRACED',
#  'W_OK',
#  'XATTR_CREATE',
#  'XATTR_REPLACE',
#  'XATTR_SIZE_MAX',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_fwalk',
#  '_get_exports_list',
#  '_spawnvef',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'chown',
#  'chroot',
#  'close',
#  'closerange',
#  'confstr',
#  'confstr_names',
#  'copy_file_range',
#  'cpu_count',
#  'ctermid',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'environb',
#  'error',
#  'eventfd',
#  'eventfd_read',
#  'eventfd_write',
#  'execl',
#  'execle',
#  'execlp',
#  'execlpe',
#  'execv',
#  'execve',
#  'execvp',
#  'execvpe',
#  'extsep',
#  'fchdir',
#  'fchmod',
#  'fchown',
#  'fdatasync',
#  'fdopen',
#  'fork',
#  'forkpty',
#  'fpathconf',
#  'fsdecode',
#  'fsencode',
#  'fspath',
#  'fstat',
#  'fstatvfs',
#  'fsync',
#  'ftruncate',
#  'fwalk',
#  'get_blocking',
#  'get_exec_path',
#  'get_inheritable',
#  'get_terminal_size',
#  'getcwd',
#  'getcwdb',
#  'getegid',
#  'getenv',
#  'getenvb',
#  'geteuid',
#  'getgid',
#  'getgrouplist',
#  'getgroups',
#  'getloadavg',
#  'getlogin',
#  'getpgid',
#  'getpgrp',
#  'getpid',
#  'getppid',
#  'getpriority',
#  'getrandom',
#  'getresgid',
#  'getresuid',
#  'getsid',
#  'getuid',
#  'getxattr',
#  'initgroups',
#  'isatty',
#  'kill',
#  'killpg',
#  'lchown',
#  'linesep',
#  'link',
#  'listdir',
#  'listxattr',
#  'lockf',
#  'login_tty',
#  'lseek',
#  'lstat',
#  'major',
#  'makedev',
#  'makedirs',
#  'memfd_create',
#  'minor',
#  'mkdir',
#  'mkfifo',
#  'mknod',
#  'name',
#  'nice',
#  'open',
#  'openpty',
#  'pardir',
#  'path',
#  'pathconf',
#  'pathconf_names',
#  'pathsep',
#  'pidfd_open',
#  'pipe',
#  'pipe2',
#  'popen',
#  'posix_fadvise',
#  'posix_fallocate',
#  'posix_spawn',
#  'posix_spawnp',
#  'pread',
#  'preadv',
#  'putenv',
#  'pwrite',
#  'pwritev',
#  'read',
#  'readlink',
#  'readv',
#  'register_at_fork',
#  'remove',
#  'removedirs',
#  'removexattr',
#  'rename',
#  'renames',
#  'replace',
#  'rmdir',
#  'scandir',
#  'sched_get_priority_max',
#  'sched_get_priority_min',
#  'sched_getaffinity',
#  'sched_getparam',
#  'sched_getscheduler',
#  'sched_param',
#  'sched_rr_get_interval',
#  'sched_setaffinity',
#  'sched_setparam',
#  'sched_setscheduler',
#  'sched_yield',
#  'sendfile',
#  'sep',
#  'set_blocking',
#  'set_inheritable',
#  'setegid',
#  'seteuid',
#  'setgid',
#  'setgroups',
#  'setns',
#  'setpgid',
#  'setpgrp',
#  'setpriority',
#  'setregid',
#  'setresgid',
#  'setresuid',
#  'setreuid',
#  'setsid',
#  'setuid',
#  'setxattr',
#  'spawnl',
#  'spawnle',
#  'spawnlp',
#  'spawnlpe',
#  'spawnv',
#  'spawnve',
#  'spawnvp',
#  'spawnvpe',
#  'splice',
#  'st',
#  'stat',
#  'stat_result',
#  'statvfs',
#  'statvfs_result',
#  'strerror',
#  'supports_bytes_environ',
#  'supports_dir_fd',
#  'supports_effective_ids',
#  'supports_fd',
#  'supports_follow_symlinks',
#  'symlink',
#  'sync',
#  'sys',
#  'sysconf',
#  'sysconf_names',
#  'system',
#  'tcgetpgrp',
#  'tcsetpgrp',
#  'terminal_size',
#  'times',
#  'times_result',
#  'truncate',
#  'ttyname',
#  'umask',
#  'uname',
#  'uname_result',
#  'unlink',
#  'unsetenv',
#  'unshare',
#  'urandom',
#  'utime',
#  'wait',
#  'wait3',
#  'wait4',
#  'waitid',
#  'waitid_result',
#  'waitpid',
#  'waitstatus_to_exitcode',
#  'walk',
#  'write',
#  'writev']

# %%
print(os.__doc__)
# Out:
# OS routines for NT or Posix depending on what system we're on.
#
# This exports:
#   - all functions from posix or nt, e.g. unlink, stat, etc.
#   - os.path is either posixpath or ntpath
#   - os.name is either 'posix' or 'nt'
#   - os.curdir is a string representing the current directory (always '.')
#   - os.pardir is a string representing the parent directory (always '..')
#   - os.sep is the (or a most common) pathname separator ('/' or '\\')
#   - os.extsep is the extension separator (always '.')
#   - os.altsep is the alternate pathname separator (None or '/')
#   - os.pathsep is the component separator used in $PATH etc
#   - os.linesep is the line separator in text files ('\r' or '\n' or '\r\n')
#   - os.defpath is the default search path for executables
#   - os.devnull is the file path of the null device ('/dev/null', etc.)
#
# Programs that import and use 'os' stand a better chance of being
# portable between different platforms.  Of course, they must then
# only use functions that are defined by all platforms (e.g., unlink
# and opendir), and leave all pathname manipulation to os.path
# (e.g., split and join).

# %%
print(f"There are {os.cpu_count()} CPU's in this system.")
# Out:
# There are 2 CPU's in this system.

# %%
try:
    f"logged_in_user_name is {os.getlogin()}"
except OSError as ex:
    print(ex)
# Out:
# [Errno 6] No such device or address

# %%
print(f"Here is a proper 10-byte random number: {str(os.urandom(10))}.")
# Out:
# Here is a proper 10-byte random number: b'\x85^\xa6\xc4\x86X5\xc0\xaan'.

# %%
print(f"Here is a proper 10-byte random number: {str(os.urandom(10))}.")
# Out:
# Here is a proper 10-byte random number: b'\xe7\x1eO\xb5\x8b\xf0G\xe6\x1a\x8b'.

# %%
print(f"Here is a proper 10-byte random number: {str(os.urandom(10))}.")
# Out:
# Here is a proper 10-byte random number: b'>\xb5ME{\x05D\xaa\xff\xfe'.

# %%
print(
    f""" 
{os.altsep =}
{os.curdir =}
{os.extsep =}
{os.linesep=}
{os.name   =}
{os.pardir =}
{os.pathsep=}
{os.sep    =}
"""
)
# Out:
#
# os.altsep =None
# os.curdir ='.'
# os.extsep ='.'
# os.linesep='\n'
# os.name   ='posix'
# os.pardir ='..'
# os.pathsep=':'
# os.sep    ='/'

# %%
os.name
# The name of the operating system dependent module imported.
# The following names have currently been registered: 'posix', 'nt', 'java'.
# Out:
# 'posix'

# %%
os.devnull  # The file path of the null device. For example: '/dev/null' for POSIX, 'nul' for Windows
# Out:
# '/dev/null'

# %%
os.defpath
# Out:
# '/bin:/usr/bin'

# %% [markdown]
# os.times
#
#     user            - user time
#     system          - system time
#     children_user   - user time of all child processes
#     children_system - system time of all child processes
#     elapsed         - elapsed real time since a fixed point in the past

# %%
os.times()
# Out:
# posix.times_result(user=0.72, system=0.2, children_user=0.0, children_system=0.0, elapsed=17180482.69)

# %%
os.urandom(10)
# Out:
# b'AP\xce\xdahm\xf6\xcb\x8b\x92'

# %%
for i in range(0, 9):
    print(i, os.urandom(i))
# Out:
# 0 b''
# 1 b'\x89'
# 2 b'\xb6\x01'
# 3 b'1\x89\xb3'
# 4 b'\xf8\xaa8\xea'
# 5 b'\x81\x8f \xcf\xda'
# 6 b'\xe8\xe7pn-*'
# 7 b'\xcd\xf2#\xf4p\x0f\xf4'
# 8 b'\x9a\xc0\xd5\xad\x1b\xf7,\xb1'

# %%
# os.environ

# %%
if os.environ['USER'] != 'codespace':
    print(
        f"""
    os.environ['OS']                    : {os.environ['OS']}
    os.environ['PROCESSOR_ARCHITECTURE']: {os.environ['PROCESSOR_ARCHITECTURE']}
    os.environ['PROCESSOR_IDENTIFIER']  : {os.environ['PROCESSOR_IDENTIFIER']}
    os.environ['PROCESSOR_LEVEL']       : {os.environ['PROCESSOR_LEVEL']}

    os.environ['TEMP']                  : {os.environ['TEMP']}
    os.environ['TMP']                   : {os.environ['TMP']}

    os.environ['COMPUTERNAME']          : {os.environ['COMPUTERNAME']}
    os.environ['HOMEDRIVE']             : {os.environ['HOMEDRIVE']}
    os.environ['USERNAME']              : {os.environ['USERNAME']}
    os.environ['USERDOMAIN']            : {os.environ['USERDOMAIN']}
    """
    )

# %%
os.getenv("PYTHON_PATH", "No Set Yet")
# Out:
# '/usr/local/python/current'

# %%
# export PYTHONSTARTUP=/path/to/your/script.py
# set PYTHONSTARTUP=C:\path\to\your\script.py

# If set, that script will execute, everytime a new interactive mode of Python is started

os.getenv("PYTHONSTARTUP", "Not Set Yet")
# Out:
# 'Not Set Yet'

# %%
os.getenv("TEMP")

# %%
# Adding new environment variable

os.putenv("A", "Apple")  # wont change the

os.getenv("A", "No such key")
# Out:
# 'No such key'

# %%
os.environ["A"] = "Apple"  # modifies environment variables

os.getenv("A", "No such key")
# Out:
# 'Apple'

# %%
for each_path in sorted(os.get_exec_path()):
    print(each_path)
# Returns the list of directories that will be searched for a named executable, when launching a process.
# Out:
# /bin
# /go/bin
# /home/codespace/.dotnet
# /home/codespace/.dotnet/tools
# /home/codespace/.local/bin
# /home/codespace/.local/bin
# /home/codespace/.php/current/bin
# /home/codespace/.python/current/bin
# /home/codespace/.ruby/current/bin
# /home/codespace/java/current/bin
# /home/codespace/nvm/current/bin
# /opt/conda/bin
# /sbin
# /usr/bin
# /usr/local/bin
# /usr/local/go/bin
# /usr/local/hugo/bin
# /usr/local/nvs
# /usr/local/oryx
# /usr/local/php/current/bin
# /usr/local/py-utils/bin
# /usr/local/python/current/bin
# /usr/local/rvm/bin
# /usr/local/rvm/gems/default/bin
# /usr/local/rvm/gems/default@global/bin
# /usr/local/rvm/rubies/default/bin
# /usr/local/sbin
# /usr/local/sdkman/bin
# /usr/local/sdkman/candidates/ant/current/bin
# /usr/local/sdkman/candidates/gradle/current/bin
# /usr/local/sdkman/candidates/java/current/bin
# /usr/local/sdkman/candidates/maven/current/bin
# /usr/local/share/nvm/current/bin
# /usr/local/share/rbenv/bin
# /usr/sbin
# /usr/share/dotnet
# /vscode/bin/linux-x64/fabdb6a30b49f79a7aba0f2ad9df9b399473380f/bin/remote-cli
# /workspaces/pythonbatchnovdec2024/.venv/bin

# %%
import getpass

assert (
    getpass.getuser()
    # == os.getlogin()
    == os.environ["USER"]  # USERNAME
    == os.getenv("USER")
)

# %%
getpass.getuser(), os.environ['USER']
# Out:
# ('codespace', 'codespace')

# %%
os.getpid()  # Return the parent’s process id.
# Out:
# 2423

# %%
os.getcwd()
# Out:
# '/workspaces/pythonbatchnovdec2024/10_Modules/04a_os_module'

# %%
print("my\newfolder")
# Out:
# my
# ewfolder

# %%
print("my\\newfolder")
# Out:
# my\newfolder

# %%
print(r"my\newfolder")
# Out:
# my\newfolder

# %%
print(r"my\newfolde\sdas\asd\asd\asd\asdasd\asd\asd")
# Out:
# my\newfolde\sdas\asd\asd\asd\asdasd\asd\asd

# %%
print("my/newfol/der")  # POSIX paths works in NT also
# Out:
# my/newfol/der

# %%
os.getcwd()
# Out:
# '/workspaces/pythonbatchnovdec2024/10_Modules/04a_os_module'

# %%
os.listdir()
# Out:
# ['a_os_module.ipynb']

# %%
os.listdir('.')
# Out:
# ['a_os_module.ipynb']

# %%
assert os.listdir('..') == os.listdir(os.pardir)

# %%
os.listdir('..')
# Out:
# ['02_sys', '03_argparse', '01_math', '04a_os_module']

# %%
os.listdir('../..')
# Out:
# ['07_functions_decorators',
#  '03_Language_components',
#  'class01',
#  '01_Introduction',
#  '10_Modules',
#  '.git',
#  '.gitignore',
#  '06_Collections',
#  '.venv',
#  '09_Iterators_generators_coroutines',
#  '05_Debugging',
#  'README.md',
#  '04_Exceptions',
#  '02_Basic']

# %%
os.listdir('../../..')
# Out:
# ['otherfile.tsf',
#  '.oryx',
#  '.codespaces',
#  'myFolder',
#  'pythonbatchnovdec2024',
#  'PythonFolder']

# %%
os.chdir('../../..')

# %%
os.getcwd()
# Out:
# '/workspaces'

# %%
os.scandir(os.getcwd())
# os.listdir returns a list, whereas os.scandir will return iterator object
# Also, os.scandir is faster and provides info about files like file size, creation time, etc

# %%
for entry in os.scandir(os.getcwd()):
    if entry.is_file():
        print(f"File: {entry.name}")
    elif entry.is_dir():
        print(f"Directory: {entry.name}")
# Out:
# File: otherfile.tsf
# Directory: .oryx
# Directory: .codespaces
# Directory: myFolder
# Directory: pythonbatchnovdec2024
# Directory: PythonFolder

# %%
os.lstat(".")
# Out:
# os.stat_result(st_mode=16879, st_ino=1835011, st_dev=1796, st_nlink=7, st_uid=1000, st_gid=0, st_size=4096, st_atime=1735945615, st_mtime=1735945604, st_ctime=1735945604)

# %%
from datetime import datetime, UTC

time_stamp = os.lstat(".").st_mtime

print(datetime.fromtimestamp(time_stamp, UTC))
# Out:
# 2025-01-03 23:06:44.993304+00:00

# %% [markdown]
# working with paths

# %%
print(
    f"""
    os.curdir : {os.curdir}
    os.pardir : {os.pardir}
    os.sep    : {os.sep}
    os.altsep : {os.altsep}
    os.extsep : {os.extsep}
    os.pathsep: {os.pathsep}  # ':' for POSIX or ';' for Windows
"""
)
# Out:
#     os.curdir : .
#     os.pardir : ..
#     os.sep    : /
#     os.altsep : None
#     os.extsep : .
#     os.pathsep: :  # ':' for POSIX or ';' for Windows

# %%
os.linesep  # '\n' for POSIX, '\r\n' for Windows
# Out:
# '\n'

# %% [markdown]
# working with directories/folder

# %%
os.mkdir('myFolder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 os.mkdir('myFolder')
#
# FileExistsError: [Errno 17] File exists: 'myFolder'

# %%
os.listdir('.')
# Out:
# ['.oryx', '.codespaces', 'myFolder', 'pythonbatchnovdec2024']

# %%
os.listdir('.')
# Out:
# ['.oryx', '.codespaces', 'myFolder', 'pythonbatchnovdec2024']

# %%
os.mkdir('myFolder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 os.mkdir('myFolder')
#
# FileExistsError: [Errno 17] File exists: 'myFolder'

# %%
os.mkdir?
# Out:
# Signature: os.mkdir(path, mode=511, *, dir_fd=None)
# Docstring:
# Create a directory.
#
# If dir_fd is not None, it should be a file descriptor open to a directory,
#   and path should be relative; path will then be relative to that directory.
# dir_fd may not be implemented on your platform.
#   If it is unavailable, using it will raise a NotImplementedError.
#
# The mode argument is ignored on Windows. Where it is used, the current umask
# value is first masked out.
# Type:      builtin_function_or_method

# %%
os.makedirs('myFolder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 os.makedirs('myFolder')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: 'myFolder'

# %%
os.makedirs?
# Out:
# Signature: os.makedirs(name, mode=511, exist_ok=False)
# Docstring:
# makedirs(name [, mode=0o777][, exist_ok=False])
#
# Super-mkdir; create a leaf directory and all intermediate ones.  Works like
# mkdir, except that any intermediate path segment (not just the rightmost)
# will be created if it does not exist. If the target directory already
# exists, raise an OSError if exist_ok is False. Otherwise no exception is
# raised.  This is recursive.
# File:      /workspaces/<frozen os>
# Type:      function

# %%
os.makedirs('myFolder', exist_ok=True)

# %%
os.makedirs('First/Second/Third', exist_ok=True)

# %%
os.listdir()
# Out:
# ['.oryx', '.codespaces', 'First', 'myFolder', 'pythonbatchnovdec2024']

# %%
os.system('tree')
# Out:
# .
# ├── First
# │   └── Second
# │       └── Third
# ├── myFolder
# └── pythonbatchnovdec2024
#     ├── 01_Introduction
#     │   ├── a_first.py
#     │   ├── b_hello_world.py
#     │   ├── c_dynamic_typing.py
#     │   ├── d_indentation_issue.py
#     │   ├── e_builtin_functions.txt
#     │   ├── f_print_syntax.py
#     │   ├── g2_print_syntax.ipynb
#     │   ├── g_print_syntax.py
#     │   ├── h_comments.py
#     │   ├── i_keywords.txt
#     │   ├── j_identifiers.py
#     │   ├── k_identifier_casing.py
#     │   ├── l_multiline_statements.py
#     │   └── m_semicolon_operator.py
#     ├── 02_Basic
#     │   ├── 02_Basics
#     │   │   ├── 01_Arithemetic Operations
#     │   │   │   ├── arithemetic_operations.ipynb
#     │   │   │   ├── b_ration_store.py
#     │   │   │   ├── c_fruit_store.py
#     │   │   │   ├── complex_numbers.ipynb
#     │   │   │   ├── d_grocery_store.py
#     │   │   │   ├── e_savings_bank.py
#     │   │   │   ├── f_bank_loan.py
#     │   │   │   └── g_feet_to_cms_conversions.py
#     │   │   └── 02_String Operations
#     │   │       ├── a_string_operations.ipynb
#     │   │       ├── b_palindrome_check.py
#     │   │       ├── c_string_attributes.ipynb
#     │   │       ├── d_string_formatting.ipynb
#     │   │       ├── e_unicode_string.ipynb
#     │   │       └── f_bytes_operations.ipynb
#     │   ├── usage_of_help.py
#     │   └── usage_of_pydoc.txt
#     ├── 03_Language_components
#     │ �� ├── 01_Relational_Operations
#     │   │   └── a_relational_operations.py
#     │   ├── 02_Logical_Operations
#     │   │   ├── a_logical_operations.py
#     │   │   ├── b_logical_operations.py
#     │   │   └── c_short_circuit.py
#     │   ├── 03_Boolean_Operations
#     │   │   └── a_boolean_operations.ipynb
#     │   ├── 04_Bitwise_Operations
#     │   │   └── a_bitwise_operations.ipynb
#     │   ├── 05_Identify_Operations
#     │   │   └── a_identify_operations.ipynb
#     │   ├── 06_Range_Function
#     │   │   └── a_range_function.ipynb
#     │   ├── 07_Conditional_Operations
#     │   │   ├── a_even_or_odd.py
#     │   │   ├── b_number_guessing_game.py
#     │   │   ├── c_office_schedule.py
#     │   ��   ├── d_vowels_n_consonants.py
#     │   │   ├── e_celsius_to_fahrenheit_conversion.py
#     │   │   ├── f_temperature_conversion.py
#     │   │   └── g_electricity_bill_generation.py
#     │   ├── 08_Structural_Pattern_Matching
#     │   │   ├── a_check_number.ipynb
#     │   │   ├── b_vowel_char_check.py
#     │   │   └── c_office_schedule.py
#     │   ├── 09_Loops
#     │   │   ├── a_for_loop.ipynb
#     │   │   ├── b_progress_bar_implementation.py
#     │   │   ├── c_progress_bar.py
#     │   │   ├── d_while_loop.ipynb
#     │   │   ├── e_multiplication_table.py
#     │   │   └── f_loops.py
#     │   └── 10_Walrus-Operator
#     │       └── a_simple_usage.ipynb
#     ├── 04_Exceptions
#     │   ├── 00_explanation.txt
#     │   ├─��� 01_exceptions_hierarchy.txt
#     │   ├── 02_exceptions_handling.ipynb
#     │   ��── 03_exception_hooks.py
#     │   └── myfile.txt
#     ├── 05_Debugging
#     │   ├── 0_explanation.txt
#     │   ├── a_using_pdb.py
#     │   ├── b_breakpoint_function.py
#     │   ├── c_breakpoint_function.py
#     │   └── d_using_ipdb.py
#     ├── 06_Collections
#     │   ├── 01_Lists
#     │   │   ├── a_list_operations.ipynb
#     │   │   └── b_copy_problem.ipynb
#     │   ├── 02_Tuples
#     │   │   └── a_tuples.ipynb
#     │   ├── 03_Sets
#     │   │   ├── a_set_opertaions.ipynb
#     │   │   ├── b_frozenset.ipynb
#     │   │   └── c_set_operators.ipynb
#     │   └── 04_Dicts
#     │       ├── a_dict_operations.ipynb
#     │       ├── comprehensions.ipynb
#     │       └── iterables_operations.ipynb
#     ├── 07_functions_decorators
#     │   ├── a_functional_programming.ipynb
#     │   └── b_advanced.ipynb
#     ├── 09_Iterators_generators_coroutines
#     │   ├── 01_Iterables
#     │   │   ├── a_iterables.ipynb
#     │   │   └── explanation.txt
#     │   ├── 02_iterators
#     │   │   ├── a_range.ipynb
#     │   │   ├── b_zip_map_filter.ipynb
#     │   │   ├── c_user_defined_iterators.ipynb
#     │   │   └── f_Itertools_module.ipynb
#     │   ├── 03_generators
#     │   │   └── a_generators.ipynb
#     │   └── 04_coroutines
#     │       └── a_coroutines.ipynb
#     ├── 10_Modules
#     │   ├── 01_math
#     │   │   └── a_math_module.ipynb
#     │   ├── 02_sys
#     │   │   ├── a_sys_module.ipynb
#     │   │   └── b_command_line_args.py
#     │   ├── 03_argparse
#     │   │   └── a_arg_parse.py
#     │   └── 04a_os_module
#     │       └── a_os_module.ipynb
#     ├── README.md
#     └── class01
#         └── hello.py
#
# 40 directories, 91 files
# 0

# %%
# creating a file
f = open("myfile.txt", "w")
f.write("my data")
f.close()

# %%
os.listdir()
# Out:
# ['myfile.txt',
#  '.oryx',
#  '.codespaces',
#  'First',
#  'myFolder',
#  'pythonbatchnovdec2024']

# %%
os.rename("myfile.txt", "otherfile.tsf")

# %%
os.listdir()
# Out:
# ['otherfile.tsf',
#  '.oryx',
#  '.codespaces',
#  'First',
#  'myFolder',
#  'pythonbatchnovdec2024']

# %%
os.rename("First", "PythonFolder")

# %%
os.system('tree')
# Out:
# .
# ├── PythonFolder
# │   └── Second
# │       └── Third
# ├── myFolder
# ├── otherfile.tsf
# └── pythonbatchnovdec2024
#     ├── 01_Introduction
#     │   ├── a_first.py
#     │   ├── b_hello_world.py
#     │   ├── c_dynamic_typing.py
#     │   ├── d_indentation_issue.py
#     │   ├── e_builtin_functions.txt
#     │   ├── f_print_syntax.py
#     │   ├── g2_print_syntax.ipynb
#     │   ├── g_print_syntax.py
#     │   ├── h_comments.py
#     │   ├── i_keywords.txt
#     │   ├── j_identifiers.py
#     │   ├── k_identifier_casing.py
#     │   ├── l_multiline_statements.py
#     │   └── m_semicolon_operator.py
#     ├── 02_Basic
#     │   ├── 02_Basics
#     │   │   ├── 01_Arithemetic Operations
#     │   │   │   ├── arithemetic_operations.ipynb
#     │   │   │   ├── b_ration_store.py
#     │   │   │   ├── c_fruit_store.py
#     │   │   │   ├── complex_numbers.ipynb
#     │   │   │   ├── d_grocery_store.py
#     │   │   │   ├── e_savings_bank.py
#     │   │   │   ├── f_bank_loan.py
#     │   │   │   └── g_feet_to_cms_conversions.py
#     │   │   └── 02_String Operations
#     │   │       ├── a_string_operations.ipynb
#     │   │       ├── b_palindrome_check.py
#     │   │       ├── c_string_attributes.ipynb
#     │   │       ├── d_string_formatting.ipynb
#     │   │       ├── e_unicode_string.ipynb
#     │   │       └── f_bytes_operations.ipynb
#     │   ├── usage_of_help.py
#     │   └── usage_of_pydoc.txt
#     ├── 03_Language_components
#     │   ├── 01_Relational_Operations
#     │   │   └── a_relational_operations.py
#     │   ├── 02_Logical_Operations
#     │   │   ├── a_logical_operations.py
#     │   │   ├── b_logical_operations.py
#     │   │   └── c_short_circuit.py
#     │   ├── 03_Boolean_Operations
#     │   │   └── a_boolean_operations.ipynb
#     │   ├── 04_Bitwise_Operations
#     │   │   └── a_bitwise_operations.ipynb
#     │   ├── 05_Identify_Operations
#     │   │   └── a_identify_operations.ipynb
#     │   ├── 06_Range_Function
#     │   │   └── a_range_function.ipynb
#     │   ├── 07_Conditional_Operations
#     │   │   ├── a_even_or_odd.py
#     │   │   ├── b_number_guessing_game.py
#     │   │   ├── c_office_schedule.py
#     │   │   ├── d_vowels_n_consonants.py
#     │   │   ├── e_celsius_to_fahrenheit_conversion.py
#     │   │   ├── f_temperature_conversion.py
#     │   │   └── g_electricity_bill_generation.py
#     │   ├── 08_Structural_Pattern_Matching
#     │   │   ├── a_check_number.ipynb
#     │   │   ├── b_vowel_char_check.py
#     │   │   └── c_office_schedule.py
#     │   ├── 09_Loops
#     │   │   ├── a_for_loop.ipynb
#     │   │   ├── b_progress_bar_implementation.py
#     │   │   ├── c_progress_bar.py
#     │   │   ├── d_while_loop.ipynb
#     │   │   ├── e_multiplication_table.py
#     │   │   └── f_loops.py
#     │   └── 10_Walrus-Operator
#     │       └── a_simple_usage.ipynb
#     ├── 04_Exceptions
#     │   ├── 00_explanation.txt
#     │   ├── 01_exceptions_hierarchy.txt
#     │   ├── 02_exceptions_handling.ipynb
#     │   ├── 03_exception_hooks.py
#     │   └── myfile.txt
#     ├── 05_Debugging
#     │   ├── 0_explanation.txt
#     │   ├── a_using_pdb.py
#     │   ├── b_breakpoint_function.py
#     │   ├── c_breakpoint_function.py
#     │   └── d_using_ipdb.py
#     ├── 06_Collections
#     │   ├── 01_Lists
#     │   │   ├── a_list_operations.ipynb
#     │   │   └── b_copy_problem.ipynb
#     │   ├── 02_Tuples
#     │   │   └── a_tuples.ipynb
#     │   ├── 03_Sets
#     │   │   ├── a_set_opertaions.ipynb
#     │   │   ├── b_frozenset.ipynb
#     │   │   └── c_set_operators.ipynb
#     │   └── 04_Dicts
#     │       ├── a_dict_operations.ipynb
#     │       ├── comprehensions.ipynb
#     │       └── iterables_operations.ipynb
#     ├── 07_functions_decorators
#     │   ├── a_functional_programming.ipynb
#     │   └── b_advanced.ipynb
#     ├── 09_Iterators_generators_coroutines
#     │   ├── 01_Iterables
#     │   │   ├── a_iterables.ipynb
#     │   │   └── explanation.txt
#     │   ├── 02_iterators
#     │   │   ├── a_range.ipynb
#     │   │   ├── b_zip_map_filter.ipynb
#     │   │   ├── c_user_defined_iterators.ipynb
#     │   │   └── f_Itertools_module.ipynb
#     │   ├── 03_generators
#     │   │   └── a_generators.ipynb
#     │   └── 04_coroutines
#     │       └── a_coroutines.ipynb
#     ├── 10_Modules
#     │   ├── 01_math
#     │   │   └── a_math_module.ipynb
#     │   ├── 02_sys
#     │   ���   ├── a_sys_module.ipynb
#     │   │   └── b_command_line_args.py
#     │   ├── 03_argparse
#     │   │   └── a_arg_parse.py
#     │   └── 04a_os_module
#     │       └── a_os_module.ipynb
#     ├── README.md
#     └── class01
#         └── hello.py
#
# 40 directories, 92 files
# 0

# %%
? os.renames
# Out:
# Signature:  os.renames(old, new)
# Docstring:
# renames(old, new)
#
# Super-rename; create directories as necessary and delete any left
# empty.  Works like rename, except creation of any intermediate
# directories needed to make the new pathname good is attempted
# first.  After the rename, directories corresponding to rightmost
# path segments of the old name will be pruned until either the
# whole path is consumed or a nonempty directory is found.
#
# Note: this function can fail with the new directory structure made
# if you lack permissions needed to unlink the leaf directory or
# file.
# File:      /workspaces/<frozen os>
# Type:      function

# %% [markdown]
# # assignment - try this os.renames

# %%
import os

# Defining file paths
old_file_name = "sample_file.txt"
new_file_path = "new_folder/renamed_file.txt"

# Create the old file for demonstration purposes
with open(old_file_name, "w") as file:
    file.write("This is the content of the sample file.")

# Use os.renames to rename the file and move it to a new directory
try:
    os.renames(old_file_name, new_file_path)
    print(f"File renamed and moved to: {new_file_path}")
except Exception as e:
    print(f"Error: {e}")

# Verifying the result
if os.path.exists(new_file_path):
    print("File successfully moved and renamed.")
else:
    print("Operation failed.")
# Out:
# File renamed and moved to: new_folder/renamed_file.txt
# File successfully moved and renamed.

# %%
os.remove("otherfile.tsf")

# %%
try:
    os.remove("myFolder")
except (PermissionError, IsADirectoryError) as ex:
    print(repr(ex))
# Out:
# IsADirectoryError(21, 'Is a directory')

# %%
os.rmdir
# Out:
# <function posix.rmdir(path, *, dir_fd=None)>

# %%
os.rmdir("myFolder")

# %%
os.system('tree')
# Out:
# .
# ├── PythonFolder
# │   └── Second
# │       └── Third
# ├── new_folder
# │   └── renamed_file.txt
# └── pythonbatchnovdec2024
#     ├── 01_Introduction
#     │   ├── a_first.py
#     │   ├── b_hello_world.py
#     │   ├── c_dynamic_typing.py
#     │   ├── d_indentation_issue.py
#     │   ├── e_builtin_functions.txt
#     │   ├── f_print_syntax.py
#     │   ├── g2_print_syntax.ipynb
#     │   ├── g_print_syntax.py
#     │   ├── h_comments.py
#     │   ├── i_keywords.txt
#     │   ├── j_identifiers.py
#     │   ├── k_identifier_casing.py
#     │   ├── l_multiline_statements.py
#     │   └── m_semicolon_operator.py
#     ├── 02_Basic
#     │   ├── 02_Basics
#     │   │   ├── 01_Arithemetic Operations
#     │   │   │   ├── arithemetic_operations.ipynb
#     │   │   │   ├── b_ration_store.py
#     │   │   │   ├── c_fruit_store.py
#     │   │   │   ├── complex_numbers.ipynb
#     │   │   │   ├── d_grocery_store.py
#     │   │   │   ├── e_savings_bank.py
#     │   │   │   ├── f_bank_loan.py
#     │   │   │   └── g_feet_to_cms_conversions.py
#     │   │   └── 02_String Operations
#     │   │       ├── a_string_operations.ipynb
#     │   │       ├── b_palindrome_check.py
#     │   │       ├── c_string_attributes.ipynb
#     │   │       ├── d_string_formatting.ipynb
#     │   │       ├── e_unicode_string.ipynb
#     │   │       └── f_bytes_operations.ipynb
#     │   ├── usage_of_help.py
#     │   └── usage_of_pydoc.txt
#     ├── 03_Language_components
#     │   ├── 01_Relational_Operations
#     │   │   └── a_relational_operations.py
#     │   ├── 02_Logical_Operations
#     │   │   ├── a_logical_operations.py
#     │   │   ├── b_logical_operations.py
#     │   │   └── c_short_circuit.py
#     │   ├── 03_Boolean_Operations
#     │   │   └── a_boolean_operations.ipynb
#     │   ├── 04_Bitwise_Operations
#     │   │   └── a_bitwise_operations.ipynb
#     │   ├── 05_Identify_Operations
#     │   │   └── a_identify_operations.ipynb
#     │   ├── 06_Range_Function
#     │   │   └── a_range_function.ipynb
#     │   ├── 07_Conditional_Operations
#     │   │   ├── a_even_or_odd.py
#     │   │   ├── b_number_guessing_game.py
#     │   │   ���── c_office_schedule.py
#     │   │   ├── d_vowels_n_consonants.py
#     │   │   ├── e_celsius_to_fahrenheit_conversion.py
#     │   │   ├── f_temperature_conversion.py
#     │   │   └── g_electricity_bill_generation.py
#     │   ├── 08_Structural_Pattern_Matching
#     │   │   ├── a_check_number.ipynb
#     │   │   ├── b_vowel_char_check.py
#     │   │   └── c_office_schedule.py
#     │   ├── 09_Loops
#     │   │   ├── a_for_loop.ipynb
#     │   │   ├── b_progress_bar_implementation.py
#     │   │   ├── c_progress_bar.py
#     │   │   ├── d_while_loop.ipynb
#     │   │   ├── e_multiplication_table.py
#     │   │   └── f_loops.py
#     │   └── 10_Walrus-Operator
#     │       └── a_simple_usage.ipynb
#     ├── 04_Exceptions
#     │   ├���─ 00_explanation.txt
#     │   ├── 01_exceptions_hierarchy.txt
#     │   ├──
# 0
#  02_exceptions_handling.ipynb
#     │   ├── 03_exception_hooks.py
#     │   └── myfile.txt
#     ├── 05_Debugging
#     │   ├── 0_explanation.txt
#     │   ├── a_using_pdb.py
#     │   ├── b_breakpoint_function.py
#     │   ├── c_breakpoint_function.py
#     │   └── d_using_ipdb.py
#     ├── 06_Collections
#     │   ├── 01_Lists
#     │   │   ├── a_list_operations.ipynb
#     │   │   └── b_copy_problem.ipynb
#     │   ├── 02_Tuples
#     │   │   └── a_tuples.ipynb
#     │   ├── 03_Sets
#     │   │   ├── a_set_opertaions.ipynb
#     │   │   ├── b_frozenset.ipynb
#     │   │   └── c_set_operators.ipynb
#     │   └── 04_Dicts
#     │       ├── a_dict_operations.ipynb
#     │       ├── comprehensions.ipynb
#     │       └── iterables_operations.ipynb
#     ├── 07_functions_decorators
#     │   ├── a_functional_programming.ipynb
#     │   └── b_advanced.ipynb
#     ├── 09_Iterators_generators_coroutines
#     │   ├── 01_Iterables
#     │   │   ├── a_iterables.ipynb
#     │   │   └── explanation.txt
#     │   ├── 02_iterators
#     │   │   ├── a_range.ipynb
#     │   │   ├── b_zip_map_filter.ipynb
#     │   │   ├── c_user_defined_iterators.ipynb
#     │   │   └── f_Itertools_module.ipynb
#     │   ├── 03_generators
#     │   │   └── a_generators.ipynb
#     │   └── 04_coroutines
#     │       └── a_coroutines.ipynb
#     ├── 10_Modules
#     │   ├── 01_math
#     │   │   └── a_math_module.ipynb
#     │   ├── 02_sys
#     │   │   ├── a_sys_module.ipynb
#     │   │   └── b_command_line_args.py
#     │   ├── 03_argparse
#     │   │   └── a_arg_parse.py
#     │   └── 04a_os_module
#     │       └── a_os_module.ipynb
#     ├── README.md
#     └── class01
#         └── hello.py
#
# 40 directories, 92 files

# %% [markdown]
# Executing commands

# %%
os.system("ipconfig")  # 1 - unsuccessfully executed command
# Out:
# sh: 1: ipconfig: not found
# 32512

# %%
os.system("ifconfig")  # 0 - successfully executed command
# Out:
# docker0: flags=4099<UP,BROADCAST,MULTICAST>  mtu 1500
#         inet 172.17.0.1  netmask 255.255.0.0  broadcast 172.17.255.255
#         ether 02:42:57:64:c2:46  txqueuelen 0  (Ethernet)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 0  bytes 0 (0.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 10.0.1.211  netmask 255.255.0.0  broadcast 10.0.255.255
#         inet6 fe80::222:48ff:fe2e:4880  prefixlen 64  scopeid 0x20<link>
#         ether 00:22:48:2e:48:80  txqueuelen 1000  (Ethernet)
#         RX packets 17252411  bytes 24018600798 (24.0 GB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 382467  bytes 96836622 (96.8 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 16812  bytes 34868478 (34.8 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 16812  bytes 34868478 (34.8 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
# 0

# %%
os.system("ping google.com")
# Out:
# sh: 1: ping: not found
# 32512

# %% [markdown]
# Get all the python files in our material

# %%
os.listdir('../../..')
# Out:
# ['var',
#  'media',
#  'proc',
#  'sys',
#  'boot',
#  'run',
#  'srv',
#  'libx32',
#  'root',
#  'dev',
#  'etc',
#  'tmp',
#  'sbin',
#  'lib32',
#  'opt',
#  'mnt',
#  'lib',
#  'lib64',
#  'bin',
#  'home',
#  'usr',
#  'vscode',
#  '.codespaces',
#  'workspaces',
#  '.dockerenv',
#  'go']

# %%
for each in os.walk("."):
    print(len(each), each)
    # break
# Out:
# 3 ('.', ['.oryx', '.codespaces', 'new_folder', 'pythonbatchnovdec2024', 'PythonFolder'], [])
# 3 ('./.oryx', [], ['build.log'])
# 3 ('./.codespaces', ['shared', '.persistedshare'], [])
# 3 ('./.codespaces/shared', ['editors'], ['codespaceStatusTool.js', '.env', '.environmentConfigurationCompleted', 'merged_devcontainer.json', 'user-secrets-envs.json', 'read-config.json', '.user-secrets.json', 'environment-variables.json', 'resource-usage.json', 'cs-agent.sock', '.env-secrets', 'postCreateOutput.json'])
# 3 ('./.codespaces/shared/editors', ['jetbrains'], [])
# 3 ('./.codespaces/shared/editors/jetbrains', ['RubyMine-2023.1.1', 'pycharm-2023.1.1', 'idea-IU-231.8770.65', 'JetBrainsRider-2023.1'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1', ['jbr', 'bin', 'lib', 'plugins', 'help', 'license'], ['product-info.json', 'RMlogo.svg', 'Install-Linux-tar.txt', 'build.txt'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr', ['include', 'conf', 'bin', 'lib', 'legal'], ['release'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/include', ['linux'], ['jawt.h', 'jvmticmlr.h', 'jni.h', 'jvmti.h', 'jdwpTransport.h', 'classfile_constants.h'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/include/linux', [], ['jawt_md.h', 'jni_md.h'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf', ['sdp', 'security', 'management'], ['logging.properties', 'sound.properties', 'net.properties'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf/sdp', [], ['sdp.conf.template'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf/security', ['policy'], ['java.policy', 'java.security'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf/security/policy', ['limited', 'unlimited'], ['README.txt'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf/security/policy/limited', [], ['default_US_export.policy', 'exempt_local.policy', 'default_local.policy'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf/security/policy/unlimited', [], ['default_US_export.policy', 'default_local.policy'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/conf/management', [], ['management.properties', 'jmxremote.password.template', 'jmxremote.access'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/bin', [], ['javac', 'serialver', 'jmap', 'jstack', 'jps', 'rmiregistry', 'java', 'javadoc', 'jcmd', 'jfr', 'jhsdb', 'jdb', 'jrunscript', 'keytool', 'jinfo', 'jstat'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/lib', ['fonts', 'server', 'security', 'jfr', 'locales'], ['libzip.so', 'libnewt_drm.so', 'libsctp.so', 'libjawt.so', 'jrt-fs.jar', 'modules', 'libawt.so', 'v8_context_snapshot.bin', 'jspawnhelper', 'libjimage.so', 'tzdb.dat', 'libsaproc.so', 'libgluegen_rt.so', 'libmanagement.so', 'libGLESv2.so', 'libnewt_head.so', 'libjsound.so', 'libj2pcsc.so', 'librmi.so', 'libjcef.so', 'libattach.so', 'chrome_200_percent.pak', 'libmanagement_agent.so', 'libnativewindow_awt.so', 'libawt_xawt.so', 'libvulkan.so.1', 'liblcms.so', 'icudtl.dat', 'libmanagement_ext.so', 'psfontj2d.properties', 'chrome-sandbox', 'libjsig.so', 'libdt_socket.so', 'psfont.properties.ja', 'libnativewindow_x11.so', 'resources.pak', 'jexec', 'chrome_100_percent.pak', 'libcef.so', 'libnet.so', 'jvm.cfg', 'libjli.so', 'libjogl_desktop.so', 'libawt_headless.so', 'libjdwp.so', 'libsplashscreen.so', 'vk_swiftshader_icd.json', 'libjavajpeg.so', 'snapshot_blob.bin', 'libmlib_image.so', 'libvk_swiftshader.so', 'jcef_helper', 'libEGL.so', 'libinstrument.so', 'ct.sym', 'libfontmanager.so', 'libverify.so', 'libj2pkcs11.so', 'libjaas.so', 'libextnet.so', 'libprefs.so', 'libnativewindow_drm.so', 'classlist', 'libjava.so', 'libnio.so', 'libj2gss.so', 'libjogl_mobile.so'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/lib/fonts', [], ['JetBrainsMono-Light.ttf', 'DroidSans.ttf', 'JetBrainsMono-MediumItalic.ttf', 'JetBrainsMono-Medium.ttf', 'FiraCode-Medium.ttf', 'JetBrainsMono-Thin.ttf', 'DroidSansMono.ttf', 'JetBrainsMono-ExtraLightItalic.ttf', 'Roboto-Thin.ttf', 'JetBrainsMono-Italic.ttf', 'DroidSerif-Bold.ttf', 'font.conf', 'DroidSans-Bold.ttf', 'Inconsolata.ttf', 'Roboto-Light.ttf', 'DroidSerif-Italic.ttf', 'DroidSerif-Regular.ttf', 'FiraCode-Retina.ttf', 'JetBrainsMono-ExtraLight.ttf', 'JetBrainsMono-ExtraBold.ttf', 'JetBrainsMono-Regular.ttf', 'Inter-SemiBoldItalic.otf', 'JetBrainsMono-ThinItalic.ttf', 'SourceCodePro-It.ttf', 'DroidSansMonoDotted.ttf', 'FiraCode-Light.ttf', 'Inter-Regular.otf', 'JetBrainsMono-ExtraBoldItalic.ttf', 'JetBrainsMono-Bold.ttf', 'Inter-SemiBold.otf', 'DroidSerif-BoldItalic.ttf', 'JetBrainsMono-BoldItalic.ttf', 'SourceCodePro-Regular.ttf', 'SourceCodePro-Bold.ttf', 'JetBrainsMono-LightItalic.ttf', 'FiraCode-Bold.ttf', 'Inter-Italic.otf', 'SourceCodePro-BoldIt.ttf', 'FiraCode-Regular.ttf', 'DroidSansMonoSlashed.ttf', 'fonts.dir'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/lib/server', [], ['libjvm.so', 'libjsig.so'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/lib/security', [], ['cacerts', 'public_suffix_list.dat', 'default.policy', 'blocked.certs'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/lib/jfr', [], ['profile.jfc', 'default.jfc'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/lib/locales', [], ['fr.pak', 'tr.pak', 'fi.pak', 'hr.pak', 'bg.pak', 'es-419.pak', 'ko.pak', 'hi.pak', 'sk.pak', 'sw.pak', 'ja.pak', 'am.pak', 'en-GB.pak', 'uk.pak', 'el.pak', 'lv.pak', 'th.pak', 'pt-PT.pak', 'sv.pak', 'ta.pak', 'af.pak', 'ml.pak', 'it.pak', 'bn.pak', 'de.pak', 'ru.pak', 'nb.pak', 'cs.pak', 'lt.pak', 'ar.pak', 'kn.pak', 'ro.pak', 'gu.pak', 'ur.pak', 'pl.pak', 'hu.pak', 'he.pak', 'nl.pak', 'en-US.pak', 'zh-TW.pak', 'ca.pak', 'fil.pak', 'id.pak', 'vi.pak', 'sl.pak', 'te.pak', 'zh-CN.pak', 'ms.pak', 'da.pak', 'es.pak', 'mr.pak', 'fa.pak', 'et.pak', 'pt-BR.pak', 'sr.pak'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal', ['jdk.jdi', 'jdk.attach', 'jdk.localedata', 'java.prefs', 'jdk.dynalink', 'jdk.javadoc', 'jdk.naming.rmi', 'java.transaction.xa', 'java.sql', 'java.net.http', 'java.management.rmi', 'jdk.unsupported.desktop', 'java.compiler', 'java.scripting', 'jdk.zipfs', 'java.instrument', 'java.logging', 'jdk.xml.dom', 'java.rmi', 'jdk.security.auth', 'jdk.httpserver', 'java.security.sasl', 'jdk.jcmd', 'jdk.management', 'java.datatransfer', 'jdk.charsets', 'java.security.jgss', 'java.se', 'java.base', 'jdk.net', 'jdk.jdwp.agent', 'java.smartcardio', 'jdk.management.jfr', 'jdk.accessibility', 'jdk.internal.le', 'jdk.compiler', 'java.xml', 'java.management', 'jdk.naming.dns', 'java.sql.rowset', 'jdk.crypto.cryptoki', 'jdk.jsobject', 'jdk.security.jgss', 'jdk.crypto.ec', 'java.desktop', 'java.naming', 'jdk.internal.ed', 'jdk.hotspot.agent', 'jdk.jfr', 'jdk.management.agent', 'jdk.internal.jvmstat', 'jdk.sctp', 'jdk.internal.vm.ci', 'java.xml.crypto', 'jdk.unsupported'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.jdi', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.attach', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.localedata', [], ['thaidict.md', 'LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION', 'cldr.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.prefs', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.dynalink', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION', 'dynalink.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.javadoc', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION', 'jquery.md', 'jqueryUI.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.naming.rmi', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.transaction.xa', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.sql', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.net.http', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.management.rmi', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.unsupported.desktop', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.compiler', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.scripting', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.zipfs', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.instrument', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.logging', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.xml.dom', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.rmi', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.security.auth', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.httpserver', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.security.sasl', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.jcmd', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.management', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.datatransfer', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.charsets', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.security.jgss', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.se', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.base', [], ['public_suffix.md', 'asm.md', 'LICENSE', 'c-libutl.md', 'unicode.md', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION', 'icu.md', 'cldr.md', 'aes.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.net', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.jdwp.agent', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.smartcardio', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION', 'pcsclite.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.management.jfr', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.accessibility', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.internal.le', [], ['LICENSE', 'jline.md', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.compiler', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.xml', [], ['LICENSE', 'jcup.md', 'xerces.md', 'ADDITIONAL_LICENSE_INFO', 'bcel.md', 'xalan.md', 'ASSEMBLY_EXCEPTION', 'dom.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.management', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.naming.dns', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.sql.rowset', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.crypto.cryptoki', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION', 'pkcs11wrapper.md', 'pkcs11cryptotoken.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.jsobject', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.security.jgss', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.crypto.ec', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.desktop', [], ['mesa3d.md', 'LICENSE', 'xwd.md', 'ADDITIONAL_LICENSE_INFO', 'jpeg.md', 'colorimaging.md', 'harfbuzz.md', 'giflib.md', 'lcms.md', 'ASSEMBLY_EXCEPTION', 'libpng.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.naming', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.internal.ed', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.hotspot.agent', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.jfr', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.management.agent', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.internal.jvmstat', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.sctp', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.internal.vm.ci', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/java.xml.crypto', [], ['LICENSE', 'santuario.md', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/jbr/legal/jdk.unsupported', [], ['LICENSE', 'ADDITIONAL_LICENSE_INFO', 'ASSEMBLY_EXCEPTION'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/bin', ['icons'], ['rubymine.png', 'rubymine64.vmoptions', 'rubymine.svg', 'idea.properties', 'ltedit.sh', 'format.sh', 'repair', 'remote-dev-server.sh', 'fsnotifier', 'brokenPlugins.db', 'rinspect.sh', 'restart.py', 'libdbm.so', 'rubymine.sh'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/bin/icons', [], ['icon-v4-1.25.db', 'icon-v4-1.5.db', 'icon-v4-1.25-d.db', 'icon-v4-2.0.db', 'icon-v4-2.0-d.db', 'icon-v4-2.5.db', 'icon-v4-1.0-d.db', 'icon-v4-1.5-d.db', 'icon-v4-2.5-d.db', 'icon-v4-1.0.db'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib', ['cds', 'pty4j', 'native', 'jna'], ['app.jar', 'rd.jar', 'externalProcess-rt.jar', 'jetbrains-annotations.jar', 'groovy.jar', 'stats.jar', 'error-prone-annotations.jar', 'protobuf.jar', 'jps-model.jar', 'junit4.jar', 'annotations-java5.jar', 'build-marker-RM-231.8770.57', 'intellij-test-discovery.jar', 'async-profiler.jar', 'byte-buddy-agent.jar', 'async-profiler-windows.jar', 'intellij-coverage-agent-1.0.706.jar', 'forms_rt.jar', 'util.jar', 'jsch-agent.jar', 'util_rt.jar', 'util-8.jar', '3rd-party-rt.jar', 'external-system-rt.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/cds', [], ['classesLogAgent.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/pty4j', ['linux'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/pty4j/linux', ['x86-64'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/pty4j/linux/x86-64', [], ['libpty.so'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/native', ['linux-x86_64'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/native/linux-x86_64', [], ['libsqliteij.so'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/jna', ['amd64'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/lib/jna/amd64', [], ['libjnidispatch.so'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins', ['featuresTrainer', 'javascript-debugger', 'microservices-ui', 'color-scheme-darcula2018', 'gateway-plugin', 'webpack', 'vagrant', 'cloudConfig', 'grid-core-impl', 'vitejs', 'html-tools', 'vuejs', 'keymap-eclipse', 'slim', 'yaml', 'platform-images', 'markdown', 'color-scheme-twilight', 'dynamicPluginsTests-performanceTesting', 'webComponents', 'space', 'copyright', 'less', 'ruby', 'remote-dev-server', 'dev', 'DatabaseTools', 'performanceTesting-async', 'performanceTesting', 'tasks-timeTracking', 'javascript-intentions', 'color-scheme-all_hallows_eve', 'webDeployment', 'color-scheme-monokai', 'restClient', 'textmate', 'liquid', 'tailwindcss', 'tasks', 'remoteRun', 'emojipicker', 'sass', 'css-impl', 'vcs-github', 'indexing-shared', 'vcs-svn', 'github-codespaces-ide', 'vcs-perforce', 'nodeJS', 'haml', 'javascript-impl', 'xml-refactoring', 'searchEverywhereMl', 'coffeescript', 'cwm-plugin', 'gateway-terminal', 'color-scheme-github', 'completionMlRanking', 'performanceTesting-yourkit', 'platform-langInjection', 'postcss', 'grid-impl', 'uml', 'editorconfig', 'terminal', 'styled-components', 'cwm-plugin-projector', 'prettierJS', 'gherkin', 'vcs-hg', 'keymap-netbeans', 'settingsSync', 'angularJS', 'karma', 'tslint', 'nextjs', 'clouds-docker-impl', 'keymap-textmate', 'color-scheme-cobalt', 'color-scheme-rails_casts', 'indexing-shared-ultimate-plugin-bundled', 'color-scheme-vibrant_ink', 'nodeJS-remoteInterpreter', 'sh', 'configurationScript', 'keymap-visualStudio', 'rubymine-customization', 'color-scheme-blackboard', 'vcs-git'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/featuresTrainer', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/featuresTrainer/lib', [], ['featuresTrainer.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/javascript-debugger', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/javascript-debugger/lib', [], ['javascript-debugger.jar', 'FirefoxConnector.jar', 'debugConnector.js', 'nashorn-debugger-9-rt.jar', 'ChromeConnector.jar', 'debugConnectionForwarder.js', 'nashorn-debugger-rt.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/microservices-ui', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/microservices-ui/lib', [], ['microservices-ui.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/color-scheme-darcula2018', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/color-scheme-darcula2018/lib', [], ['color-scheme-darcula2018.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/gateway-plugin', ['resources', 'lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/gateway-plugin/resources', [], ['gateway.vmoptions'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/gateway-plugin/lib', ['remote-dev-workers', 'gateway-standalone'], ['gateway-plugin.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/gateway-plugin/lib/remote-dev-workers', [], ['remote-dev-worker-linux-amd64', 'remote-dev-worker-darwin-amd64', 'remote-dev-worker-linux-arm64', 'remote-dev-worker-windows-arm64.exe', 'remote-dev-worker-darwin-arm64', 'remote-dev-worker-windows-amd64.exe'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/gateway-plugin/lib/gateway-standalone', [], ['gateway.jar', 'gateway.core.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/webpack', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/webpack/lib', [], ['webpack.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vagrant', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vagrant/lib', [], ['vagrant.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/cloudConfig', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/cloudConfig/lib', [], ['cloudConfig.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/grid-core-impl', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/grid-core-impl/lib', [], ['grid-core.jar', 'jdbc-console-types.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vitejs', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vitejs/lib', [], ['vitejs.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/html-tools', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/html-tools/lib', [], ['html-tools.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs', ['vue-service', 'lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service', ['node_modules'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules', ['htmlparser2', 'ws-typescript-vue-plugin', 'entities'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules/htmlparser2', ['lib'], ['package.json', 'LICENSE', 'README.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules/htmlparser2/lib', [], ['WritableStream.js', 'index.js', 'MultiplexHandler.js', 'Parser.js', 'FeedHandler.js', 'CollectingHandler.js', 'Tokenizer.js'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules/ws-typescript-vue-plugin', [], ['index.js', 'package.json', 'transformVueSfcFile.js', 'vueScriptCache.js'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules/entities', ['lib'], ['package.json', 'LICENSE', 'readme.md'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules/entities/lib', ['maps'], ['index.js', 'decode.js', 'encode.js', 'decode_codepoint.js'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/vue-service/node_modules/entities/lib/maps', [], ['legacy.json', 'decode.json', 'xml.json', 'entities.json'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/vuejs/lib', [], ['vuejs.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/keymap-eclipse', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/keymap-eclipse/lib', [], ['keymap-eclipse.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/slim', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/slim/lib', [], ['slim.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/yaml', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/yaml/lib', [], ['yaml.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/platform-images', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/platform-images/lib', [], ['platform-images.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/markdown', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/markdown/lib', [], ['markdown.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/color-scheme-twilight', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/color-scheme-twilight/lib', [], ['color-scheme-twilight.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/dynamicPluginsTests-performanceTesting', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/dynamicPluginsTests-performanceTesting/lib', [], ['dynamicPluginsTests-performanceTesting.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/webComponents', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/webComponents/lib', [], ['webComponents.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/space', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/space/lib', [], ['space-java-jps.jar', 'space.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/copyright', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/copyright/lib', [], ['copyright.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/less', ['lib'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/less/lib', [], ['less.jar'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby', ['rubystubs', 'rubysigs', 'lib', 'rb'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs', ['rubystubs21', 'rubystubs26', 'rubystubs32', 'rubystubs27', 'rubystubs30', 'rubystubs24', 'rubystubs19', 'rubystubs23', 'rubystubs18', 'rubystubs22', 'rubystubs31', 'rubystubs20', 'rubystubs25'], [])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs21', [], ['argf.rb', 'pty.rb', 'tk_callback_entry.rb', 'float.rb', 'date_time.rb', 'data.rb', 'syslog.rb', 'ip_socket.rb', 'fixnum.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'mutex.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'tk_local_jump_error.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'tk_callback_continue.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'sized_queue.rb', 'readline.rb', 'basic_object.rb', 'tk_kernel.rb', 'digest.rb', 'sdbm.rb', 'regexp_error.rb', 'tcl_tk_ip.rb', 'nkf.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'bignum.rb', 'method.rb', 'socket.rb', 'tk_callback_return.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'tk_util.rb', 'win32_ole_variable.rb', 'queue.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'tk_object.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'tk_callback_retry.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'sdbm_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'jruby_builtin.rb', 'dl.rb', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'jruby_extensions.rb', 'condition_variable.rb', 'kernel.rb', 'key_error.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'tk_callback_redo.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'tcl_tk_lib.rb', 'win32_ole_method.rb', 'basic_socket.rb', 'type_error.rb', 'strscan.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'local_jump_error.rb', 'tk_callback_break.rb', 'security_error.rb', 'enumerator.rb', 'tk_callback_throw.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs26', [], ['argf.rb', 'pty.rb', 'float.rb', 'date_time.rb', 'data.rb', 'closed_queue_error.rb', 'syslog.rb', 'ip_socket.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'mutex.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'win32_ole_record.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'sized_queue.rb', 'readline.rb', 'basic_object.rb', 'digest.rb', 'sdbm.rb', 'regexp_error.rb', 'nkf.rb', 'unicode_normalize.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'method.rb', 'socket.rb', 'win32.rb', 'frozen_error.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'win32_ole_variable.rb', 'queue.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'cgi.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'sdbm_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'jruby_builtin.rb', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'jruby_extensions.rb', 'condition_variable.rb', 'kernel.rb', 'key_error.rb', 'warning.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'win32_ole_method.rb', 'basic_socket.rb', 'type_error.rb', 'strscan.rb', 'win32_ole_query_interface_error.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'uncaught_throw_error.rb', 'local_jump_error.rb', 'security_error.rb', 'enumerator.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs32', [], ['argf.rb', 'pty.rb', 'refinement.rb', 'markup_reference.rb', 'float.rb', 'date_time.rb', 'data.rb', 'closed_queue_error.rb', 'syslog.rb', 'ip_socket.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'comparable.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'no_matching_pattern_key_error.rb', 'socket_error.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'r_doc.rb', 'symbol.rb', 'json.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'readline.rb', 'basic_object.rb', 'digest.rb', 'regexp_error.rb', 'nkf.rb', 'unicode_normalize.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'ractor.rb', 'method.rb', 'socket.rb', 'win32.rb', 'frozen_error.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'cgi.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'kernel.rb', 'key_error.rb', 'warning.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'unbound_method.rb', 'encoding_error.rb', 'monitor.rb', 'basic_socket.rb', 'type_error.rb', 'no_matching_pattern_error.rb', 'strscan.rb', 'win32_ole_query_interface_error.rb', 'encoding.rb', 'no_memory_error.rb', 'uncaught_throw_error.rb', 'local_jump_error.rb', 'security_error.rb', 'enumerator.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs27', [], ['argf.rb', 'pty.rb', 'float.rb', 'date_time.rb', 'data.rb', 'closed_queue_error.rb', 'syslog.rb', 'ip_socket.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'mutex.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'win32_ole_record.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'sized_queue.rb', 'readline.rb', 'basic_object.rb', 'digest.rb', 'sdbm.rb', 'regexp_error.rb', 'nkf.rb', 'unicode_normalize.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'method.rb', 'socket.rb', 'win32.rb', 'frozen_error.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'win32_ole_variable.rb', 'queue.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'cgi.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'sdbm_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'jruby_builtin.rb', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'jruby_extensions.rb', 'condition_variable.rb', 'kernel.rb', 'key_error.rb', 'pool.rb', 'warning.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'win32_ole_method.rb', 'monitor.rb', 'basic_socket.rb', 'type_error.rb', 'no_matching_pattern_error.rb', 'strscan.rb', 'win32_ole_query_interface_error.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'uncaught_throw_error.rb', 'local_jump_error.rb', 'security_error.rb', 'enumerator.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs30', [], ['argf.rb', 'pty.rb', 'float.rb', 'date_time.rb', 'closed_queue_error.rb', 'syslog.rb', 'ip_socket.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'mutex.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'win32_ole_record.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'sized_queue.rb', 'readline.rb', 'basic_object.rb', 'digest.rb', 'regexp_error.rb', 'nkf.rb', 'unicode_normalize.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'ractor.rb', 'method.rb', 'socket.rb', 'win32.rb', 'frozen_error.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'win32_ole_variable.rb', 'queue.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'cgi.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'condition_variable.rb', 'kernel.rb', 'key_error.rb', 'pool.rb', 'warning.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'win32_ole_method.rb', 'monitor.rb', 'basic_socket.rb', 'type_error.rb', 'no_matching_pattern_error.rb', 'strscan.rb', 'win32_ole_query_interface_error.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'uncaught_throw_error.rb', 'local_jump_error.rb', 'security_error.rb', 'enumerator.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs24', [], ['argf.rb', 'pty.rb', 'float.rb', 'date_time.rb', 'data.rb', 'closed_queue_error.rb', 'syslog.rb', 'ip_socket.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'win32_ole_record.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'sized_queue.rb', 'readline.rb', 'basic_object.rb', 'digest.rb', 'sdbm.rb', 'regexp_error.rb', 'nkf.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'method.rb', 'socket.rb', 'win32.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'win32_ole_variable.rb', 'queue.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'cgi.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'sdbm_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'jruby_builtin.rb', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'jruby_extensions.rb', 'condition_variable.rb', 'kernel.rb', 'key_error.rb', 'warning.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'win32_ole_method.rb', 'basic_socket.rb', 'type_error.rb', 'strscan.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'uncaught_throw_error.rb', 'local_jump_error.rb', 'security_error.rb', 'enumerator.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs19', [], ['argf.rb', 'pty.rb', 'tk_callback_entry.rb', 'float.rb', 'date_time.rb', 'data.rb', 'syslog.rb', 'tms.rb', 'ip_socket.rb', 'fixnum.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'mutex.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'constants.rb', 'tk_local_jump_error.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'tk_callback_continue.rb', 'fcntl.rb', 'etc.rb', 'iconv.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'readline.rb', 'basic_object.rb', 'tk_kernel.rb', 'digest.rb', 'sdbm.rb', 'regexp_error.rb', 'tcl_tk_ip.rb', 'nkf.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'bignum.rb', 'method.rb', 'socket.rb', 'tk_callback_return.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'tk_util.rb', 'win32_ole_variable.rb', 'nil_class.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'tk_object.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'tk_callback_retry.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'sdbm_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'jruby_builtin.rb', 'dl.rb', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'curses.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'jruby_extensions.rb', 'kernel.rb', 'key_error.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'tk_callback_redo.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'tcl_tk_lib.rb', 'win32_ole_method.rb', 'basic_socket.rb', 'type_error.rb', 'strscan.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'local_jump_error.rb', 'tk_callback_break.rb', 'security_error.rb', 'enumerator.rb', 'tk_callback_throw.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# 3 ('./.codespaces/shared/editors/jetbrains/RubyMine-2023.1.1/plugins/ruby/rubystubs/rubystubs23', [], ['pty.rb', 'tk_callback_entry.rb', 'float.rb', 'date_time.rb', 'data.rb', 'closed_queue_error.rb', 'syslog.rb', 'ip_socket.rb', 'fixnum.rb', 'not_implemented_error.rb', 'script_error.rb', 'ripper.rb', 'dbm_error.rb', 'integer.rb', 'float_domain_error.rb', 'marshal.rb', 'win32_ole_record.rb', 'comparable.rb', 'win32_ole_event.rb', 'file_test.rb', 'string.rb', 'tcp_socket.rb', 'tk_local_jump_error.rb', 'gdbm.rb', 'socket_error.rb', 'win32_ole_param.rb', 'stringio.rb', 'racc.rb', 'zero_division_error.rb', 'range_error.rb', 'io_error.rb', 'tk_callback_continue.rb', 'fcntl.rb', 'etc.rb', 'argument_error.rb', 'file.rb', 'ruby_vm.rb', 'unix_server.rb', 'symbol.rb', 'json.rb', 'dbm.rb', 'proc.rb', 'no_method_error.rb', 'thread.rb', 'gdbm_error.rb', 'regexp.rb', 'false_class.rb', 'struct.rb', 'win32_ole_type.rb', 'sized_queue.rb', 'readline.rb', 'basic_object.rb', 'tk_kernel.rb', 'digest.rb', 'sdbm.rb', 'regexp_error.rb', 'tcl_tk_ip.rb', 'nkf.rb', 'gc.rb', 'time.rb', 'dir.rb', 'socks_socket.rb', 'system_call_error.rb', 'bignum.rb', 'method.rb', 'socket.rb', 'tk_callback_return.rb', 'stop_iteration.rb', 'fiber_error.rb', 'binding.rb', 'big_decimal.rb', 'class.rb', 'random.rb', 'open_ssl.rb', 'udp_socket.rb', 'system_exit.rb', 'unix_socket.rb', 'win32_ole_runtime_error.rb', 'tk_util.rb', 'win32_ole_variable.rb', 'queue.rb', 'nil_class.rb', 'trace_point.rb', 'system_stack_error.rb', 'psych.rb', 'complex.rb', 'range.rb', 'tk_object.rb', 'hash.rb', 'thread_error.rb', 'syntax_error.rb', 'name_error.rb', 'interrupt.rb', 'date.rb', 'cgi.rb', 'object_space.rb', 'numeric.rb', 'tcp_server.rb', 'tk_callback_retry.rb', 'coverage.rb', 'match_data.rb', 'load_error.rb', 'sdbm_error.rb', 'fiddle.rb', 'addrinfo.rb', 'errno.rb', 'pathname.rb', 'io.rb', '.ruby-version', 'jruby_builtin.rb', 'enumerable.rb', 'rational.rb', 'module.rb', 'math.rb', 'object.rb', 'eof_error.rb', 'signal_exception.rb', 'index_error.rb', 'process.rb', 'true_class.rb', 'win32_ole_typelib.rb', 'continuation.rb', 'global_variables.rb', 'zlib.rb', 'array.rb', 'jruby_extensions.rb', 'condition_variable.rb', 'kernel.rb', 'key_error.rb', 'signal.rb', 'big_math.rb', 'runtime_error.rb', 'exception.rb', 'win32_ole.rb', 'thread_group.rb', 'tk_callback_redo.rb', 'unbound_method.rb', 'encoding_error.rb', 'gdbm_fatal_error.rb', 'tcl_tk_lib.rb', 'win32_ole_method.rb', 'basic_socket.rb', 'type_error.rb', 'strscan.rb', 'encoding.rb', 'win32_ole_variant.rb', 'no_memory_error.rb', 'uncaught_throw_error.rb', 'local_jump_error.rb', 'tk_callback_break.rb', 'security_error.rb', 'enumerator.rb', 'tk_callback_throw.rb', 'standard_error.rb', 'env.rb', 'fiber.rb'])
# ...
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/core/tests/daft_extension', ['__pycache__'], ['daft_extension.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/core/tests/daft_extension/__pycache__', [], ['daft_extension.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/core/profile', [], ['README_STARTUP'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/core/magics', ['__pycache__'], ['packaging.py', 'logging.py', 'script.py', 'execution.py', '__init__.py', 'osm.py', 'config.py', 'history.py', 'basic.py', 'namespace.py', 'ast_mod.py', 'auto.py', 'extension.py', 'pylab.py', 'display.py', 'code.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/core/magics/__pycache__', [], ['pylab.cpython-312.pyc', 'packaging.cpython-312.pyc', 'ast_mod.cpython-312.pyc', 'auto.cpython-312.pyc', 'code.cpython-312.pyc', 'osm.cpython-312.pyc', 'history.cpython-312.pyc', 'display.cpython-312.pyc', 'config.cpython-312.pyc', 'logging.cpython-312.pyc', 'namespace.cpython-312.pyc', 'basic.cpython-312.pyc', '__init__.cpython-312.pyc', 'script.cpython-312.pyc', 'execution.cpython-312.pyc', 'extension.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/utils', ['__pycache__', 'tests'], ['py3compat.py', 'ipstruct.py', 'capture.py', 'data.py', 'timing.py', 'importstring.py', 'tz.py', 'terminal.py', 'colorable.py', 'shimmodule.py', '__init__.py', 'syspathcontext.py', 'path.py', 'PyColorize.py', 'ulinecache.py', 'coloransi.py', 'wildcard.py', 'module_paths.py', 'jsonutil.py', '_process_win32.py', 'encoding.py', 'tokenutil.py', 'dir2.py', 'sentinel.py', 'localinterfaces.py', 'tempdir.py', 'decorators.py', 'version.py', 'sysinfo.py', 'openpy.py', 'eventful.py', '_process_posix.py', '_process_emscripten.py', 'signatures.py', '_sysinfo.py', '_process_cli.py', 'text.py', 'log.py', 'frame.py', 'docs.py', 'strdispatch.py', 'io.py', 'traitlets.py', '_process_common.py', 'generics.py', 'contexts.py', '_process_win32_controller.py', 'daemonize.py', 'process.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/utils/__pycache__', [], ['openpy.cpython-312.pyc', 'ulinecache.cpython-312.pyc', 'frame.cpython-312.pyc', 'shimmodule.cpython-312.pyc', '_process_emscripten.cpython-312.pyc', 'ipstruct.cpython-312.pyc', 'generics.cpython-312.pyc', 'syspathcontext.cpython-312.pyc', 'log.cpython-312.pyc', 'text.cpython-312.pyc', 'timing.cpython-312.pyc', 'coloransi.cpython-312.pyc', 'strdispatch.cpython-312.pyc', '_process_cli.cpython-312.pyc', 'tz.cpython-312.pyc', 'signatures.cpython-312.pyc', 'sentinel.cpython-312.pyc', 'daemonize.cpython-312.pyc', 'terminal.cpython-312.pyc', 'jsonutil.cpython-312.pyc', 'sysinfo.cpython-312.pyc', '_process_common.cpython-312.pyc', 'encoding.cpython-312.pyc', 'version.cpython-312.pyc', 'io.cpython-312.pyc', 'tempdir.cpython-312.pyc', '_process_win32.cpython-312.pyc', 'module_paths.cpython-312.pyc', 'py3compat.cpython-312.pyc', 'eventful.cpython-312.pyc', 'wildcard.cpython-312.pyc', 'tokenutil.cpython-312.pyc', 'localinterfaces.cpython-312.pyc', '__init__.cpython-312.pyc', 'importstring.cpython-312.pyc', 'docs.cpython-312.pyc', 'data.cpython-312.pyc', 'capture.cpython-312.pyc', 'path.cpython-312.pyc', 'dir2.cpython-312.pyc', '_process_posix.cpython-312.pyc', '_process_win32_controller.cpython-312.pyc', 'colorable.cpython-312.pyc', 'PyColorize.cpython-312.pyc', 'contexts.cpython-312.pyc', 'decorators.cpython-312.pyc', '_sysinfo.cpython-312.pyc', 'process.cpython-312.pyc', 'traitlets.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/utils/tests', ['__pycache__'], ['test_module_paths.py', 'test_imports.py', '__init__.py', 'test_tempdir.py', 'test_wildcard.py', 'test_dir2.py', 'test_openpy.py', 'test_tokenutil.py', 'test_shimmodule.py', 'test_deprecated.py', 'test_process.py', 'test_io.py', 'test_text.py', 'test_capture.py', 'test_path.py', 'test_importstring.py', 'test_pycolorize.py', 'test_sysinfo.py', 'test_decorators.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/utils/tests/__pycache__', [], ['test_importstring.cpython-312.pyc', 'test_path.cpython-312.pyc', 'test_decorators.cpython-312.pyc', 'test_tokenutil.cpython-312.pyc', 'test_imports.cpython-312.pyc', 'test_text.cpython-312.pyc', 'test_io.cpython-312.pyc', 'test_wildcard.cpython-312.pyc', 'test_process.cpython-312.pyc', 'test_tempdir.cpython-312.pyc', 'test_sysinfo.cpython-312.pyc', 'test_deprecated.cpython-312.pyc', 'test_shimmodule.cpython-312.pyc', '__init__.cpython-312.pyc', 'test_capture.cpython-312.pyc', 'test_dir2.cpython-312.pyc', 'test_pycolorize.cpython-312.pyc', 'test_module_paths.cpython-312.pyc', 'test_openpy.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/__pycache__', [], ['__main__.cpython-312.pyc', 'conftest.cpython-312.pyc', 'display.cpython-312.pyc', 'consoleapp.cpython-312.pyc', '__init__.cpython-312.pyc', 'paths.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/external', ['__pycache__', 'tests'], ['__init__.py', 'qt_loaders.py', 'qt_for_kernel.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/external/__pycache__', [], ['qt_loaders.cpython-312.pyc', '__init__.cpython-312.pyc', 'qt_for_kernel.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/external/tests', ['__pycache__'], ['__init__.py', 'test_qt_loaders.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/external/tests/__pycache__', [], ['test_qt_loaders.cpython-312.pyc', '__init__.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal', ['pt_inputhooks', '__pycache__', 'shortcuts', 'tests'], ['console.py', 'interactiveshell.py', '__init__.py', 'ptutils.py', 'prompts.py', 'magics.py', 'embed.py', 'ipapp.py', 'debugger.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks', ['__pycache__'], ['gtk3.py', 'wx.py', '__init__.py', 'gtk4.py', 'qt.py', 'asyncio.py', 'glut.py', 'pyglet.py', 'tk.py', 'gtk.py', 'osx.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/pt_inputhooks/__pycache__', [], ['tk.cpython-312.pyc', 'glut.cpython-312.pyc', 'gtk4.cpython-312.pyc', 'gtk3.cpython-312.pyc', 'asyncio.cpython-312.pyc', 'osx.cpython-312.pyc', 'wx.cpython-312.pyc', '__init__.cpython-312.pyc', 'pyglet.cpython-312.pyc', 'gtk.cpython-312.pyc', 'qt.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/__pycache__', [], ['console.cpython-312.pyc', 'prompts.cpython-312.pyc', 'ipapp.cpython-312.pyc', 'ptutils.cpython-312.pyc', 'interactiveshell.cpython-312.pyc', 'embed.cpython-312.pyc', '__init__.cpython-312.pyc', 'magics.cpython-312.pyc', 'debugger.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/shortcuts', ['__pycache__'], ['__init__.py', 'auto_match.py', 'auto_suggest.py', 'filters.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/shortcuts/__pycache__', [], ['auto_suggest.cpython-312.pyc', 'filters.cpython-312.pyc', 'auto_match.cpython-312.pyc', '__init__.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/tests', ['__pycache__'], ['test_shortcuts.py', '__init__.py', 'test_help.py', 'test_interactivshell.py', 'test_debug_magic.py', 'test_pt_inputhooks.py', 'test_embed.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/terminal/tests/__pycache__', [], ['test_embed.cpython-312.pyc', 'test_help.cpython-312.pyc', 'test_shortcuts.cpython-312.pyc', 'test_interactivshell.cpython-312.pyc', 'test_debug_magic.cpython-312.pyc', '__init__.cpython-312.pyc', 'test_pt_inputhooks.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/lib', ['__pycache__', 'tests'], ['pretty.py', 'demo.py', 'clipboard.py', '__init__.py', 'latextools.py', 'lexers.py', 'guisupport.py', 'deepreload.py', 'display.py', 'backgroundjobs.py', 'editorhooks.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/lib/__pycache__', [], ['guisupport.cpython-312.pyc', 'backgroundjobs.cpython-312.pyc', 'deepreload.cpython-312.pyc', 'demo.cpython-312.pyc', 'clipboard.cpython-312.pyc', 'latextools.cpython-312.pyc', 'display.cpython-312.pyc', '__init__.cpython-312.pyc', 'pretty.cpython-312.pyc', 'editorhooks.cpython-312.pyc', 'lexers.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/lib/tests', ['__pycache__'], ['test_latextools.py', 'test.wav', 'test_imports.py', 'test_clipboard.py', '__init__.py', 'test_deepreload.py', 'test_backgroundjobs.py', 'test_display.py', 'test_pygments.py', 'test_lexers.py', 'test_editorhooks.py', 'test_pretty.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/IPython/lib/tests/__pycache__', [], ['test_imports.cpython-312.pyc', 'test_backgroundjobs.cpython-312.pyc', 'test_deepreload.cpython-312.pyc', 'test_clipboard.cpython-312.pyc', 'test_lexers.cpython-312.pyc', 'test_latextools.cpython-312.pyc', 'test_pretty.cpython-312.pyc', 'test_display.cpython-312.pyc', 'test_editorhooks.cpython-312.pyc', '__init__.cpython-312.pyc', 'test_pygments.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/asttokens', ['__pycache__'], ['asttokens.py', 'util.py', '__init__.py', 'mark_tokens.py', 'py.typed', 'version.py', 'line_numbers.py', 'astroid_compat.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/asttokens/__pycache__', [], ['asttokens.cpython-312.pyc', 'astroid_compat.cpython-312.pyc', 'version.cpython-312.pyc', 'line_numbers.cpython-312.pyc', 'mark_tokens.cpython-312.pyc', '__init__.cpython-312.pyc', 'util.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/matplotlib_inline', ['__pycache__'], ['__init__.py', 'config.py', 'backend_inline.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/matplotlib_inline/__pycache__', [], ['backend_inline.cpython-312.pyc', 'config.cpython-312.pyc', '__init__.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/tornado-6.4.2.dist-info', [], ['RECORD', 'INSTALLER', 'top_level.txt', 'WHEEL', 'LICENSE', 'METADATA'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/ptyprocess', ['__pycache__'], ['ptyprocess.py', 'util.py', '__init__.py', '_fork_pty.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/ptyprocess/__pycache__', [], ['_fork_pty.cpython-312.pyc', 'ptyprocess.cpython-312.pyc', '__init__.cpython-312.pyc', 'util.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/debugpy-1.8.11.dist-info', [], ['entry_points.txt', 'RECORD', 'INSTALLER', 'top_level.txt', 'WHEEL', 'LICENSE', 'METADATA'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/pip-24.3.1.dist-info', [], ['entry_points.txt', 'RECORD', 'INSTALLER', 'AUTHORS.txt', 'LICENSE.txt', 'top_level.txt', 'WHEEL', 'METADATA'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/six-1.17.0.dist-info', [], ['RECORD', 'INSTALLER', 'top_level.txt', 'WHEEL', 'LICENSE', 'METADATA'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/parso-0.8.4.dist-info', [], ['RECORD', 'INSTALLER', 'AUTHORS.txt', 'LICENSE.txt', 'top_level.txt', 'WHEEL', 'METADATA'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/jupyter_core', ['utils', '__pycache__'], ['troubleshoot.py', '__init__.py', 'application.py', '__main__.py', 'migrate.py', 'py.typed', 'command.py', 'version.py', 'paths.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/jupyter_core/utils', ['__pycache__'], ['__init__.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/jupyter_core/utils/__pycache__', [], ['__init__.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/jupyter_core/__pycache__', [], ['__main__.cpython-312.pyc', 'troubleshoot.cpython-312.pyc', 'migrate.cpython-312.pyc', 'version.cpython-312.pyc', 'application.cpython-312.pyc', '__init__.cpython-312.pyc', 'command.cpython-312.pyc', 'paths.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/prompt_toolkit-3.0.48.dist-info', [], ['AUTHORS.rst', 'RECORD', 'INSTALLER', 'top_level.txt', 'WHEEL', 'LICENSE', 'METADATA'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/stack_data', ['__pycache__'], ['__init__.py', 'utils.py', 'serializing.py', 'core.py', 'formatting.py', 'py.typed', 'version.py'])
# 3 ('./pythonbatchnovdec2024/.venv/lib/python3.12/site-packages/stack_data/__pycache__', [], ['utils.cpython-312.pyc', 'core.cpython-312.pyc', 'version.cpython-312.pyc', 'serializing.cpython-312.pyc', 'formatting.cpython-312.pyc', '__init__.cpython-312.pyc'])
# 3 ('./pythonbatchnovdec2024/.venv/share', ['jupyter', 'man'], [])
# 3 ('./pythonbatchnovdec2024/.venv/share/jupyter', ['kernels'], [])
# 3 ('./pythonbatchnovdec2024/.venv/share/jupyter/kernels', ['python3'], [])
# 3 ('./pythonbatchnovdec2024/.venv/share/jupyter/kernels/python3', [], ['logo-svg.svg', 'logo-64x64.png', 'logo-32x32.png', 'kernel.json'])
# 3 ('./pythonbatchnovdec2024/.venv/share/man', ['man1'], [])
# 3 ('./pythonbatchnovdec2024/.venv/share/man/man1', [], ['ipython.1'])
# 3 ('./pythonbatchnovdec2024/.venv/bin', [], ['activate.fish', 'activate_this.py', 'ipython', 'jupyter-kernelspec', 'jupyter-kernel', 'activate', 'pip-3.12', 'jupyter-run', 'python3', 'jupyter-troubleshoot', 'activate.nu', 'pip', 'jupyter-migrate', 'debugpy', 'pygmentize', 'pip3', 'ipython3', 'jupyter', 'python3.12', 'python', 'activate.csh', 'activate.ps1', 'pip3.12'])
# 3 ('./pythonbatchnovdec2024/09_Iterators_generators_coroutines', ['03_generators', '04_coroutines', '01_Iterables', '02_iterators'], [])
# 3 ('./pythonbatchnovdec2024/09_Iterators_generators_coroutines/03_generators', [], ['a_generators.ipynb'])
# 3 ('./pythonbatchnovdec2024/09_Iterators_generators_coroutines/04_coroutines', [], ['a_coroutines.ipynb'])
# 3 ('./pythonbatchnovdec2024/09_Iterators_generators_coroutines/01_Iterables', [], ['a_iterables.ipynb', 'explanation.txt'])
# 3 ('./pythonbatchnovdec2024/09_Iterators_generators_coroutines/02_iterators', [], ['b_zip_map_filter.ipynb', 'a_range.ipynb', 'f_Itertools_module.ipynb', 'c_user_defined_iterators.ipynb'])
# 3 ('./pythonbatchnovdec2024/05_Debugging', [], ['c_breakpoint_function.py', 'd_using_ipdb.py', '0_explanation.txt', 'b_breakpoint_function.py', 'a_using_pdb.py'])
# 3 ('./pythonbatchnovdec2024/04_Exceptions', [], ['01_exceptions_hierarchy.txt', 'myfile.txt', '02_exceptions_handling.ipynb', '00_explanation.txt', '03_exception_hooks.py'])
# 3 ('./pythonbatchnovdec2024/02_Basic', ['02_Basics'], ['usage_of_pydoc.txt', 'usage_of_help.py'])
# 3 ('./pythonbatchnovdec2024/02_Basic/02_Basics', ['01_Arithemetic Operations', '02_String Operations'], [])
# 3 ('./pythonbatchnovdec2024/02_Basic/02_Basics/01_Arithemetic Operations', [], ['f_bank_loan.py', 'b_ration_store.py', 'complex_numbers.ipynb', 'arithemetic_operations.ipynb', 'c_fruit_store.py', 'g_feet_to_cms_conversions.py', 'e_savings_bank.py', 'd_grocery_store.py'])
# 3 ('./pythonbatchnovdec2024/02_Basic/02_Basics/02_String Operations', [], ['c_string_attributes.ipynb', 'b_palindrome_check.py', 'f_bytes_operations.ipynb', 'e_unicode_string.ipynb', 'a_string_operations.ipynb', 'd_string_formatting.ipynb'])
# 3 ('./PythonFolder', ['Second'], [])
# 3 ('./PythonFolder/Second', ['Third'], [])
# 3 ('./PythonFolder/Second/Third', [], [])

# %%
# assignment - like a anti-virus scan, scan all the executables in your operating system. Based on OS, executable need to be taken


executables = []

def is_executable(file_name):
    return file_name.lower().endswith((".exe", ".bat", ".cmd", ".msi", ".dll"))

for each_dir, list_of_folders, list_of_files in os.walk('/workspaces/PythonNovDec24'):
    if list_of_files:
        for each_file in list_of_files:
            if is_executable(each_file):
                executables.append(each_file)

if executables:
    print("Virus found")
else:
    print("No virus found")
# Out:
# No virus found

# %% [markdown]
# Working with paths

# %%
os.path.basename("/home/user/temp.txt")  # doesnt check for presence of file
# Out:
# 'temp.txt'

# %%
os.path.dirname("/home/user/temp.txt")
# Out:
# '/home/user'

# %%
os.path.abspath("temp.txt")
# Out:
# '/workspaces/temp.txt'

# %%
os.getcwd()
# Out:
# '/workspaces'

# %%
os.path.realpath("/home/user/temp.txt")  # no validation for presence of file
# Out:
# '/home/user/temp.txt'

# %%
os.path.splitext("/home/user/temp.log")
# Out:
# ('/home/user/temp', '.log')

# %%
os.path.splitdrive("/home/user/temp.txt")
# Out:
# ('', '/home/user/temp.txt')

# %%
os.path.extsep
# Out:
# '.'

# %%
import sys

if sys.platform == "win32":
    path_joiner = "\\"
else:
    path_joiner = "/"

print(path_joiner, os.sep)
assert path_joiner == os.sep
# Out:
# / /

# %%
os.path.join("css", "america")
# Out:
# 'css/america'

# %%
os.path.join("css", "america", "asdas", "sad", "dfgd")
# Out:
# 'css/america/asdas/sad/dfgd'

# %%
"\\".join(("css", "america", "asdas", "sad", "dfgd"))
# Out:
# 'css\\america\\asdas\\sad\\dfgd'

# %%
(os.sep).join(("css", "america", "asdas", "sad", "dfgd"))
# Out:
# 'css/america/asdas/sad/dfgd'

# %%
assert os.path.join("css", "america", "asdas", "sad", "dfgd") == (os.sep).join(
    ("css", "america", "asdas", "sad", "dfgd")
)

# %%
new_path = os.path.join("css", "america", "asdas", "sad", "dfgd")
new_path
# Out:
# 'css/america/asdas/sad/dfgd'

# %% [markdown]
# Attributes which work only on Linux

# %%
# os.getloadavg(): This function returns the system load average over the last 1, 5, and 15 minutes as a tuple.
#  This function is not available on Windows.

os.getloadavg()
# Out:
# (0.46, 0.25, 0.2)

# %% [markdown]
# os.pipe(): This function creates a pair of connected file descriptors, which can be used for interprocess communication. This function is not available on Windows.
#
# os.chroot(): This function changes the root directory of the current process to the specified directory. This function is not available on Windows.
#
# os.fchown(): This function changes the owner and group of a file, given the file descriptor. This function is not available on Windows.
#
# os.setresuid(): This function sets the real, effective, and saved user IDs of the current process. This function is not available on Windows.
#
# os.setresgid(): This function sets the real, effective, and saved group IDs of the current process. This function is not available on Windows.
